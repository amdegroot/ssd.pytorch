# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
a=np.random.randint(0,10,[23,])
b=np.expand_dims(a, axis=0)

# %%
a=np.zeros([1,5])
a.shape==(1,5)
# Out:
# True

# %%
b=a[:,:3]
b.shape
# Out:
# (1, 3)

# %%
c=np.expand_dims(a,axis=1) # [23,]到[23,1]
c.shape
# Out:
# (23, 1)

# %%
d=np.random.randint(0,10,[23,4])

# %%
e=np.hstack((d,c))
e.shape
# Out:
# (23, 5)

# %%
f=np.zeros([1,5])
f.shape
# Out:
# (1, 5)

# %%
for index in np.arange(10):
    print(index)
    index += (-1,1)[index==0]
    print(index)
# Out:
# 0
# 1
# 1
# 0
# 2
# 1
# 3
# 2
# 4
# 3
# 5
# 4
# 6
# 5
# 7
# 6
# 8
# 7
# 9
# 8
# /home/mk/anaconda3/envs/pytorch36/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
img=cv2.imread('/home/mk/data/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg')

# %%
newimg=cv2.rectangle(img, (174, 101), (349, 351), (0,255,0), 4)
print(newimg)
plt.figure('newfig')
plt.imshow(newimg)
plt.show()
# Out:
# [[[208 220 208]
#   [206 218 206]
#   [205 215 203]
#   ...
#   [ 72  58  82]
#   [ 56  43  65]
#   [175 164 184]]
#
#  [[210 222 210]
#   [209 221 209]
#   [210 220 208]
#   ...
#   [ 72  68  93]
#   [ 79  77  97]
#   [175 173 192]]
#
#  [[209 220 210]
#   [211 222 212]
#   [210 221 211]
#   ...
#   [ 91 112 133]
#   [101 119 136]
#   [173 189 205]]
#
#  ...
#
#  [[ 89  97 156]
#   [ 86  95 152]
#   [ 80  87 144]
#   ...
#   [ 51  32  47]
#   [ 69  53  64]
#   [245 232 240]]
#
#  [[ 86  97 155]
#   [ 87  96 153]
#   [ 84  91 148]
#   ...
#   [ 56  37  52]
#   [ 71  55  66]
#   [243 230 238]]
#
#  [[ 85  96 154]
#   [ 87  98 155]
#   [ 85  92 149]
#   ...
#   [ 69  50  65]
#   [ 81  65  76]
#   [250 237 245]]]

# %%
np.finfo(np.float32).max
# Out:
# 3.4028235e+38

# %%
a=[197,163,120]
a=np.array(a)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-baf63ceaa63c> in <module>
#       1 a=[197,163,120]
# ----> 2 a=np.array(a)
#       3 a
#
# NameError: name 'np' is not defined

# %%
a=cv2.imread('/home/mk/data/VOCdevkit/VOC2012/JPEGImages/2007_000027.jpg')
a
plt.figure('newfig')
plt.subplot(121)
plt.imshow(a)
b=a.astype(np.float32)/a.max()
plt.subplot(122)
plt.imshow(b)
plt.show()

# %%
b=a.astype(np.float32)/a.max()
cv2.imshow('b',b)
cv2.waitKey()

# %%
x=[21, -2]

# %%
print(x)
# Out:
# [21, -2]

# %%
import numpy as np
a=np.random.randint(1, 10, (10,10))
a
# Out:
# array([[4, 2, 7, 2, 1, 7, 4, 3, 9, 8],
#        [3, 9, 7, 9, 1, 1, 4, 7, 2, 3],
#        [5, 5, 2, 3, 4, 1, 5, 9, 2, 5],
#        [7, 9, 9, 8, 9, 1, 2, 2, 1, 4],
#        [8, 1, 7, 4, 3, 3, 7, 1, 5, 2],
#        [4, 8, 6, 2, 7, 9, 3, 3, 1, 3],
#        [5, 5, 7, 8, 7, 5, 6, 5, 1, 3],
#        [1, 4, 1, 5, 1, 5, 7, 1, 3, 4],
#        [8, 4, 4, 5, 7, 4, 4, 5, 3, 4],
#        [3, 7, 7, 4, 7, 4, 1, 3, 1, 2]])

# %%
a[[0,4],:]=a[[4,0],:]

# %%
a
# for idx, v in enumerate(a, 2):
#     print(str(idx)+': '+str(v)) # 编号从start开始，但是遍历顺序不变
# Out:
# array([[8, 1, 7, 4, 3, 3, 7, 1, 5, 2],
#        [3, 9, 7, 9, 1, 1, 4, 7, 2, 3],
#        [5, 5, 2, 3, 4, 1, 5, 9, 2, 5],
#        [7, 9, 9, 8, 9, 1, 2, 2, 1, 4],
#        [4, 2, 7, 2, 1, 7, 4, 3, 9, 8],
#        [4, 8, 6, 2, 7, 9, 3, 3, 1, 3],
#        [5, 5, 7, 8, 7, 5, 6, 5, 1, 3],
#        [1, 4, 1, 5, 1, 5, 7, 1, 3, 4],
#        [8, 4, 4, 5, 7, 4, 4, 5, 3, 4],
#        [3, 7, 7, 4, 7, 4, 1, 3, 1, 2]])
